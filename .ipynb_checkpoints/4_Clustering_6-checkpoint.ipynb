# %%
! pip install -U seaborn

# %%
import json
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns

# %%
seaborn.__version__
# Out:
# '0.11.1'

# %%
df = pd.read_csv('my_top_with_features.csv')

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'index', 'endTime', 'artistName', 'trackName', 'msPlayed',
#        'counts', 'trackID', 'danceability', 'energy', 'key', 'loudness',
#        'mode', 'speechiness', 'acousticness', 'instrumentalness', 'liveness',
#        'valence', 'tempo', 'type', 'id', 'uri', 'track_href', 'analysis_url',
#        'duration_ms', 'time_signature'],
#       dtype='object')

# %%
df = df[['artistName', 'trackName', 'counts',
        'danceability', 'energy', 'key', 'loudness', 'mode',
       'speechiness', 'acousticness', 'instrumentalness', 'liveness',
       'valence', 'tempo']]

# %%
df.isnull().sum()
# Out:
# artistName          0
# trackName           0
# counts              0
# danceability        1
# energy              1
# key                 1
# loudness            1
# mode                1
# speechiness         1
# acousticness        1
# instrumentalness    1
# liveness            1
# valence             1
# tempo               1
# dtype: int64

# %%
df.dropna(inplace=True)

# %%
for i in df.describe().columns:
    sns.histplot(data=df, x=i)
    plt.show()

# %%
(df.artistName.value_counts()).to_frame().reset_index()
# Out:
#                  index  artistName
# 0                 Muse          50
# 1                JAY-Z          27
# 2       Oliver Heldens          20
# 3          Post Malone          19
# 4             Coldplay          19
# ..                 ...         ...
# 492  The White Stripes           1
# 493         James Hype           1
# 494         Bebe Rexha           1
# 495  Natalie Imbruglia           1
# 496              Foals           1
#
# [497 rows x 2 columns]

# %%
sns.scatterplot(data=df, x='danceability', y='tempo', hue='key')

# %%
X = df[['danceability', 'energy', 'key', 'loudness', 'mode',
       'speechiness', 'acousticness', 'instrumentalness', 'liveness',
       'valence', 'tempo']]

# %%
from sklearn.cluster import KMeans
from sklearn.preprocessing import StandardScaler

# %%
# Standarize features
scaler = StandardScaler()
X_std = scaler.fit_transform(X)

# %%
# Create k-mean object
clt = KMeans(n_clusters=6, n_init=100)

# Train model
model = clt.fit(X_std)

# %%
labels = pd.Series(model.labels_)

# %%
labels.unique()
# Out:
# array([1, 7, 9, 0, 2, 5, 4, 8, 3, 6])

# %%
df['labels_6'] = pd.Series(model.labels_)

# %%
df[df['labels_6'] == 4].artistName.unique()
# Out:
# array(['Vicetone', 'Carnage', 'Crankdat', 'Dillon Francis', 'BROHUG',
#        'Calippo', 'Tiësto', 'Ship Wrek', 'BLR', 'DJ Snake', 'Jauz',
#        'Tujamo', 'Veorra', 'Magnificence', 'Teamworx', 'JVST SAY YES',
#        'Duke & Jones', 'Laidback Luke', 'HI-LO', 'Enrico Sangiuliano',
#        'Mike Cervello', 'Dr. Fresch', 'Dropgun', 'MADDOW', 'Quintino',
#        'Storm Queen', 'Sikdope', 'Zomboy', 'Oliver Heldens',
#        'Yellow Claw', 'Eric Prydz', 'Valentino Khan', 'Mike Candys',
#        'David Guetta', 'Kideko', 'Darude', 'Crazy Frog',
#        'GOLEC UORKIESTRA', 'KSHMR', 'Justice', 'Jason Derulo', 'Coldplay',
#        'The Weather Girls', 'Don Diablo', 'Galantis', 'Jay Pryor',
#        'Maroon 5', 'Crowded House', 'Madison Mars', 'MØ', 'JOYRYDE',
#        'Becky Hill', 'ITZY', 'Diplo', 'FISHER', 'Madonna', 'D.O.D',
#        'Carl Cox', 'Reinier Zonneveld'], dtype=object)

# %%
inertions = []
num_clusters = range(2, 12)

# Populating distortions for various clusters
for i in num_clusters:
    clt = KMeans(n_clusters=i, n_init=100)
    model = clt.fit(X_std)
    inertions.append(model.inertia_)

# %%
# Plotting elbow plot data
elbow_plot_data = pd.DataFrame({'num_clusters': num_clusters,
'inertions': inertions})
sns.lineplot(x='num_clusters', y='inertions',
data = elbow_plot_data)
plt.show()

# %%
df.groupby('labels_6').describe()
# Out:
#          counts                                                       \
#           count       mean        std  min   25%   50%    75%    max
# labels_6
# 0.0       106.0  13.066038  12.938145  6.0  7.25   9.0  14.00  124.0
# 1.0       117.0  13.965812  13.506660  6.0  7.00  10.0  14.00   91.0
# 2.0       296.0  15.445946  15.668725  6.0  7.00  10.0  15.00  101.0
# 3.0       204.0  16.034314  14.028957  6.0  7.00  10.0  20.25   88.0
# 4.0        77.0  18.207792  14.899080  6.0  8.00  11.0  23.00   67.0
# 5.0       317.0  16.627760  16.545495  6.0  7.00  10.0  17.00  112.0
#
#          danceability            ... labels_4      labels_7            \
#                 count      mean  ...      75%  max    count      mean
# labels_6                         ...
# 0.0             106.0  0.618953  ...      0.0  0.0    106.0  5.584906
# 1.0             117.0  0.680701  ...      3.0  3.0    117.0  0.128205
# 2.0             296.0  0.685865  ...      3.0  3.0    296.0  2.939189
# 3.0             204.0  0.557328  ...      3.0  3.0    204.0  3.436275
# 4.0              77.0  0.678078  ...      2.0  2.0     77.0  4.896104
# 5.0             317.0  0.682202  ...      1.0  1.0    317.0  2.028391
#
#
#                std  min  25%  50%  75%  max
# labels_6
# 0.0       1.178117  1.0  6.0  6.0  6.0  6.0
# 1.0       0.464952  0.0  0.0  0.0  0.0  4.0
# 2.0       0.398750  0.0  3.0  3.0  3.0  4.0
# 3.0       1.118962  0.0  4.0  4.0  4.0  5.0
# 4.0       0.640403  1.0  5.0  5.0  5.0  5.0
# 5.0       0.492811  0.0  2.0  2.0  2.0  4.0
#
# [6 rows x 120 columns]

# %%
sns.histplot(df.groupby('labels_6').key.value_counts())

# %%
df.labels_6.value_counts()
# Out:
# 5.0    317
# 2.0    296
# 3.0    204
# 1.0    117
# 0.0    106
# 4.0     77
# Name: labels_6, dtype: int64

# %%
from sklearn.manifold import TSNE
import matplotlib.pyplot as plt

# %%
tsne = TSNE(n_components=2, perplexity=20)

# %%
data_2d = tsne.fit_transform(X)

# %%
# colours = ['r', 'g', 'b', 'c', 'm', 'y', 'k', 'pink', 'orange', 'purple']
colours = ['r', 'g', 'b', 'c', 'm', 'y']

# %%
sns.scatterplot(data_2d[:,0], data_2d[:,1], hue=labels, palette=colours)
# Out:
# C:\Users\Agata\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
df_artists = pd.read_csv('artists.csv')

# %%
df_artists[df_artists['name'] == "Reinier Zonneveld"]
# Out:
#                            id  followers           genres               name  \
# 56188  21A7bhIL1m6CNZn8y57PIZ    81850.0  ['dark techno']  Reinier Zonneveld
#
#        popularity
# 56188          56

# %%
df_artists.genres.value_counts()
# Out:
# []                                                                     805733
# ['background piano']                                                      293
# ['calming instrumental']                                                  255
# ['background music']                                                      245
# ['barnmusik']                                                             224
#                                                                         ...
# ['american shoegaze', 'bay area indie']                                     1
# ['latin metal', 'metal gotico', 'mexican metal', 'rock en espanol']         1
# ['alternative pop', 'boston rock', 'gbvfi', 'riot grrrl']                   1
# ['classic iskelma', 'dragspel', 'harmonikka']                               1
# ['caribbean metal', 'christian hardcore', 'puerto rican metal']             1
# Name: genres, Length: 48788, dtype: int64

# %%
df_artists.drop_duplicates(inplace=True)

# %%
df_genres = df.merge(df_artists, how='left', left_on='artistName', right_on='name')

# %%
df_genres
# Out:
#              artistName                                    trackName  counts  \
# 0            Don Diablo                                          Bad      20
# 1            Don Diablo                                          Bad      20
# 2              Vicetone                                   Astronomia      23
# 3               Xxanaxx      Nie znajdziesz mnie (feat. TEN TYP MES)       9
# 4                MEDUZA                                 Lose Control      50
# ...                 ...                                          ...     ...
# 1205              D.O.D                                      Incline       7
# 1206  Reinier Zonneveld                   Move Your Body To The Beat      19
# 1207           Carl Cox                                      Inferno      14
# 1208  Reinier Zonneveld                                    Hard Gaan      27
# 1209  Reinier Zonneveld  Resurrection - Reinier Zonneveld 2020 Remix      12
#
#       danceability  energy   key  loudness  mode  speechiness  acousticness  \
# 0            0.791   0.738   0.0    -5.197   1.0       0.0732       0.40600
# 1            0.791   0.738   0.0    -5.197   1.0       0.0732       0.40600
# 2            0.653   0.945   5.0    -2.634   1.0       0.0960       0.00561
# 3            0.656   0.660  10.0   -10.104   0.0       0.1900       0.04440
# 4            0.598   0.526  10.0    -8.659   0.0       0.0415       0.12900
# ...            ...     ...   ...       ...   ...          ...           ...
# 1205         0.708   0.993  11.0     1.479   0.0       0.1540       0.00417
# 1206         0.866   0.828   8.0    -8.704   1.0       0.2030       0.20300
# 1207         0.675   0.823   1.0    -6.534   0.0       0.0887       0.01310
# 1208         0.684   0.897   6.0    -5.598   0.0       0.3910       0.04440
# 1209         0.676   0.754   1.0    -6.272   0.0       0.0448       0.00242
#
#       ...    tempo  labels  labels_4  labels_7  labels_6  \
# 0     ...  123.927     1.0       3.0       3.0       2.0
# 1     ...  123.927     1.0       3.0       3.0       2.0
# 2     ...  126.093     6.0       2.0       5.0       4.0
# 3     ...  127.047     0.0       1.0       0.0       1.0
# 4     ...  123.935     0.0       0.0       2.0       5.0
# ...   ...      ...     ...       ...       ...       ...
# 1205  ...  126.057     6.0       2.0       5.0       4.0
# 1206  ...  133.004     3.0       1.0       4.0       5.0
# 1207  ...  125.995     6.0       2.0       5.0       4.0
# 1208  ...  144.429     6.0       2.0       5.0       4.0
# 1209  ...  130.974     NaN       NaN       NaN       NaN
#
#                           id  followers  \
# 0     1l2ekx5skC4gJH8djERwh1  1725294.0
# 1     5pkdwIiDACB2SbNhk9DHtQ      868.0
# 2     0daugAjUgbJSqdlyYNwIbT   366482.0
# 3     7ntlRmHlTFId8K07kOsxTY    47271.0
# 4     0xRXCcSX89eobfrshSVdyu   406658.0
# ...                      ...        ...
# 1205  0Cs47vvRsPgEfliBU9KDiB    24281.0
# 1206  21A7bhIL1m6CNZn8y57PIZ    81850.0
# 1207  19SmlbABtI4bXz864MLqOS   566067.0
# 1208  21A7bhIL1m6CNZn8y57PIZ    81850.0
# 1209  21A7bhIL1m6CNZn8y57PIZ    81850.0
#
#                                                  genres               name  \
# 0     ['dance pop', 'edm', 'electro house', 'future ...         Don Diablo
# 1                                                    []         Don Diablo
# 2     ['edm', 'electro house', 'gaming edm', 'pop da...           Vicetone
# 3     ['polish alternative', 'polish indie', 'polish...            Xxanaxx
# 4     ['dance pop', 'edm', 'pop dance', 'pop house',...             MEDUZA
# ...                                                 ...                ...
# 1205  ['edm', 'electro house', 'progressive electro ...              D.O.D
# 1206                                    ['dark techno']  Reinier Zonneveld
# 1207  ['house', 'schranz', 'tech house', 'uk tech ho...           Carl Cox
# 1208                                    ['dark techno']  Reinier Zonneveld
# 1209                                    ['dark techno']  Reinier Zonneveld
#
#       popularity
# 0           75.0
# 1            0.0
# 2           72.0
# 3           40.0
# 4           83.0
# ...          ...
# 1205        55.0
# 1206        56.0
# 1207        55.0
# 1208        56.0
# 1209        56.0
#
# [1210 rows x 23 columns]

# %%
df_genres
# Out:
# Empty DataFrame
# Columns: [artistName, trackName, counts, danceability, energy, key, loudness, mode, speechiness, acousticness, instrumentalness, liveness, valence, tempo, labels, labels_4, labels_7, labels_6, id, followers, genres, name, popularity]
# Index: []
#
# [0 rows x 23 columns]
